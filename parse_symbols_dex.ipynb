# %%
import requests
import pandas as pd
import json

url = "https://token.jup.ag/strict"

# Fetch data from the URL
response = requests.get(url)
data = response.json()

# Extract symbol names
symbol_names = [token["symbol"] for token in data]

# Create a DataFrame
df = pd.DataFrame({"Symbol": symbol_names})

# %%
symbols = df.drop_duplicates(subset="Symbol", keep="first")

# %%
symbols[symbols.duplicated]
# Out:
# Empty DataFrame
# Columns: [Symbol]
# Index: []

# %%
symbols.head()
# Out:
#   Symbol
# 0    SOL
# 1   USDC
# 2   USDT
# 3   $WIF
# 4   Bonk

# %%
# Export DataFrame to CSV
symbols.to_csv("symbol_names.csv", index=False)

print("Symbol names exported to symbol_names.csv")
# Out:
# Symbol names exported to symbol_names.csv

# %%
import pandas as pd
import requests

# Load the CSV file into a DataFrame
df = pd.read_csv('symbol_names.csv')

# Create an empty DataFrame to store the results
result_df = pd.DataFrame(columns=['Symbol', 'Price_vs_USDC'])

# Loop through each symbol in the CSV file
for symbol in df['Symbol']:
    # Make the API request
    url = f'https://price.jup.ag/v4/price?ids={symbol}&vsToken=USDC'
    response = requests.get(url)
    
    # Check if the request was successful (status code 200)
    if response.status_code == 200:
        try:
            data = response.json()
            price_vs_usdc = data['data'][symbol]['price']
            
            # Append the result to the DataFrame
            result_df = result_df.append({'Symbol': symbol, 'Price_vs_USDC': price_vs_usdc}, ignore_index=True)
        except KeyError:
            print(f"Data not available for {symbol}")
    else:
        print(f"Error fetching data for {symbol}. Status code: {response.status_code}")

# Save the result DataFrame to a new CSV file
result_df.to_csv('symbol_prices_vs_usdc.csv', index=False)
# Out:
# C:\Users\Latitude\AppData\Local\Temp\ipykernel_12760\1613849081.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'Symbol': symbol, 'Price_vs_USDC': price_vs_usdc}, ignore_index=True)
# C:\Users\Latitude\AppData\Local\Temp\ipykernel_12760\1613849081.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'Symbol': symbol, 'Price_vs_USDC': price_vs_usdc}, ignore_index=True)
# C:\Users\Latitude\AppData\Local\Temp\ipykernel_12760\1613849081.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'Symbol': symbol, 'Price_vs_USDC': price_vs_usdc}, ignore_index=True)
# C:\Users\Latitude\AppData\Local\Temp\ipykernel_12760\1613849081.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'Symbol': symbol, 'Price_vs_USDC': price_vs_usdc}, ignore_index=True)
# C:\Users\Latitude\AppData\Local\Temp\ipykernel_12760\1613849081.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'Symbol': symbol, 'Price_vs_USDC': price_vs_usdc}, ignore_index=True)
# C:\Users\Latitude\AppData\Local\Temp\ipykernel_12760\1613849081.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'Symbol': symbol, 'Price_vs_USDC': price_vs_usdc}, ignore_index=True)
# C:\Users\Latitude\AppData\Local\Temp\ipykernel_12760\1613849081.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'Symbol': symbol, 'Price_vs_USDC': price_vs_usdc}, ignore_index=True)
# Data not available for ROCKY
# C:\Users\Latitude\AppData\Local\Temp\ipykernel_12760\1613849081.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'Symbol': symbol, 'Price_vs_USDC': price_vs_usdc}, ignore_index=True)
# C:\Users\Latitude\AppData\Local\Temp\ipykernel_12760\1613849081.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'Symbol': symbol, 'Price_vs_USDC': price_vs_usdc}, ignore_index=True)
# C:\Users\Latitude\AppData\Local\Temp\ipykernel_12760\1613849081.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'Symbol': symbol, 'Price_vs_USDC': price_vs_usdc}, ignore_index=True)
# C:\Users\Latitude\AppData\Local\Temp\ipykernel_12760\1613849081.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'Symbol': symbol, 'Price_vs_USDC': price_vs_usdc}, ignore_index=True)
# C:\Users\Latitude\AppData\Local\Temp\ipykernel_12760\1613849081.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'Symbol': symbol, 'Price_vs_USDC': price_vs_usdc}, ignore_index=True)
# C:\Users\Latitude\AppData\Local\Temp\ipykernel_12760\1613849081.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'Symbol': symbol, 'Price_vs_USDC': price_vs_usdc}, ignore_index=True)
# C:\Users\Latitude\AppData\Local\Temp\ipykernel_12760\1613849081.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'Symbol': symbol, 'Price_vs_USDC': price_vs_usdc}, ignore_index=True)
# C:\Users\Latitude\AppData\Local\Temp\ipykernel_12760\1613849081.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'Symbol': symbol, 'Price_vs_USDC': price_vs_usdc}, ignore_index=True)
# C:\Users\Latitude\AppData\Local\Temp\ipykernel_12760\1613849081.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'Symbol': symbol, 'Price_vs_USDC': price_vs_usdc}, ignore_index=True)
# C:\Users\Latitude\AppData\Local\Temp\ipykernel_12760\1613849081.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'Symbol': symbol, 'Price_vs_USDC': price_vs_usdc}, ignore_index=True)
# C:\Users\Latitude\AppData\Local\Temp\ipykernel_12760\1613849081.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'Symbol': symbol, 'Price_vs_USDC': price_vs_usdc}, ignore_index=True)
# C:\Users\Latitude\AppData\Local\Temp\ipykernel_12760\1613849081.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'Symbol': symbol, 'Price_vs_USDC': price_vs_usdc}, ignore_index=True)
# C:\Users\Latitude\AppData\Local\Temp\ipykernel_12760\1613849081.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'Symbol': symbol, 'Price_vs_USDC': price_vs_usdc}, ignore_index=True)
# C:\Users\Latitude\AppData\Local\Temp\ipykernel_12760\1613849081.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'Symbol': symbol, 'Price_vs_USDC': price_vs_usdc}, ignore_index=True)
# C:\Users\Latitude\AppData\Local\Temp\ipykernel_12760\1613849081.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'Symbol': symbol, 'Price_vs_USDC': price_vs_usdc}, ignore_index=True)
# C:\Users\Latitude\AppData\Local\Temp\ipykernel_12760\1613849081.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'Symbol': symbol, 'Price_vs_USDC': price_vs_usdc}, ignore_index=True)
# C:\Users\Latitude\AppData\Local\Temp\ipykernel_12760\1613849081.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'Symbol': symbol, 'Price_vs_USDC': price_vs_usdc}, ignore_index=True)
# C:\Users\Latitude\AppData\Local\Temp\ipykernel_12760\1613849081.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'Symbol': symbol, 'Price_vs_USDC': price_vs_usdc}, ignore_index=True)
# C:\Users\Latitude\AppData\Local\Temp\ipykernel_12760\1613849081.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'Symbol': symbol, 'Price_vs_USDC': price_vs_usdc}, ignore_index=True)
# C:\Users\Latitude\AppData\Local\Temp\ipykernel_12760\1613849081.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'Symbol': symbol, 'Price_vs_USDC': price_vs_usdc}, ignore_index=True)
# C:\Users\Latitude\AppData\Local\Temp\ipykernel_12760\1613849081.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'Symbol': symbol, 'Price_vs_USDC': price_vs_usdc}, ignore_index=True)
# C:\Users\Latitude\AppData\Local\Temp\ipykernel_12760\1613849081.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'Symbol': symbol, 'Price_vs_USDC': price_vs_usdc}, ignore_index=True)
# C:\Users\Latitude\AppData\Local\Temp\ipykernel_12760\1613849081.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'Symbol': symbol, 'Price_vs_USDC': price_vs_usdc}, ignore_index=True)
# C:\Users\Latitude\AppData\Local\Temp\ipykernel_12760\1613849081.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'Symbol': symbol, 'Price_vs_USDC': price_vs_usdc}, ignore_index=True)
# C:\Users\Latitude\AppData\Local\Temp\ipykernel_12760\1613849081.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'Symbol': symbol, 'Price_vs_USDC': price_vs_usdc}, ignore_index=True)
# C:\Users\Latitude\AppData\Local\Temp\ipykernel_12760\1613849081.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'Symbol': symbol, 'Price_vs_USDC': price_vs_usdc}, ignore_index=True)
# C:\Users\Latitude\AppData\Local\Temp\ipykernel_12760\1613849081.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'Symbol': symbol, 'Price_vs_USDC': price_vs_usdc}, ignore_index=True)
# C:\Users\Latitude\AppData\Local\Temp\ipykernel_12760\1613849081.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'Symbol': symbol, 'Price_vs_USDC': price_vs_usdc}, ignore_index=True)
# C:\Users\Latitude\AppData\Local\Temp\ipykernel_12760\1613849081.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'Symbol': symbol, 'Price_vs_USDC': price_vs_usdc}, ignore_index=True)
# C:\Users\Latitude\AppData\Local\Temp\ipykernel_12760\1613849081.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'Symbol': symbol, 'Price_vs_USDC': price_vs_usdc}, ignore_index=True)
# C:\Users\Latitude\AppData\Local\Temp\ipykernel_12760\1613849081.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'Symbol': symbol, 'Price_vs_USDC': price_vs_usdc}, ignore_index=True)
# C:\Users\Latitude\AppData\Local\Temp\ipykernel_12760\1613849081.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'Symbol': symbol, 'Price_vs_USDC': price_vs_usdc}, ignore_index=True)
# C:\Users\Latitude\AppData\Local\Temp\ipykernel_12760\1613849081.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'Symbol': symbol, 'Price_vs_USDC': price_vs_usdc}, ignore_index=True)
# C:\Users\Latitude\AppData\Local\Temp\ipykernel_12760\1613849081.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'Symbol': symbol, 'Price_vs_USDC': price_vs_usdc}, ignore_index=True)
# C:\Users\Latitude\AppData\Local\Temp\ipykernel_12760\1613849081.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'Symbol': symbol, 'Price_vs_USDC': price_vs_usdc}, ignore_index=True)
# C:\Users\Latitude\AppData\Local\Temp\ipykernel_12760\1613849081.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'Symbol': symbol, 'Price_vs_USDC': price_vs_usdc}, ignore_index=True)
# C:\Users\Latitude\AppData\Local\Temp\ipykernel_12760\1613849081.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'Symbol': symbol, 'Price_vs_USDC': price_vs_usdc}, ignore_index=True)
# C:\Users\Latitude\AppData\Local\Temp\ipykernel_12760\1613849081.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'Symbol': symbol, 'Price_vs_USDC': price_vs_usdc}, ignore_index=True)
# C:\Users\Latitude\AppData\Local\Temp\ipykernel_12760\1613849081.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'Symbol': symbol, 'Price_vs_USDC': price_vs_usdc}, ignore_index=True)
# C:\Users\Latitude\AppData\Local\Temp\ipykernel_12760\1613849081.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'Symbol': symbol, 'Price_vs_USDC': price_vs_usdc}, ignore_index=True)
# C:\Users\Latitude\AppData\Local\Temp\ipykernel_12760\1613849081.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'Symbol': symbol, 'Price_vs_USDC': price_vs_usdc}, ignore_index=True)
# C:\Users\Latitude\AppData\Local\Temp\ipykernel_12760\1613849081.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'Symbol': symbol, 'Price_vs_USDC': price_vs_usdc}, ignore_index=True)
# C:\Users\Latitude\AppData\Local\Temp\ipykernel_12760\1613849081.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'Symbol': symbol, 'Price_vs_USDC': price_vs_usdc}, ignore_index=True)
# C:\Users\Latitude\AppData\Local\Temp\ipykernel_12760\1613849081.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'Symbol': symbol, 'Price_vs_USDC': price_vs_usdc}, ignore_index=True)
# C:\Users\Latitude\AppData\Local\Temp\ipykernel_12760\1613849081.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'Symbol': symbol, 'Price_vs_USDC': price_vs_usdc}, ignore_index=True)
# C:\Users\Latitude\AppData\Local\Temp\ipykernel_12760\1613849081.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'Symbol': symbol, 'Price_vs_USDC': price_vs_usdc}, ignore_index=True)
# C:\Users\Latitude\AppData\Local\Temp\ipykernel_12760\1613849081.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'Symbol': symbol, 'Price_vs_USDC': price_vs_usdc}, ignore_index=True)
# C:\Users\Latitude\AppData\Local\Temp\ipykernel_12760\1613849081.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'Symbol': symbol, 'Price_vs_USDC': price_vs_usdc}, ignore_index=True)
# C:\Users\Latitude\AppData\Local\Temp\ipykernel_12760\1613849081.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'Symbol': symbol, 'Price_vs_USDC': price_vs_usdc}, ignore_index=True)
# C:\Users\Latitude\AppData\Local\Temp\ipykernel_12760\1613849081.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'Symbol': symbol, 'Price_vs_USDC': price_vs_usdc}, ignore_index=True)
# C:\Users\Latitude\AppData\Local\Temp\ipykernel_12760\1613849081.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'Symbol': symbol, 'Price_vs_USDC': price_vs_usdc}, ignore_index=True)
# C:\Users\Latitude\AppData\Local\Temp\ipykernel_12760\1613849081.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'Symbol': symbol, 'Price_vs_USDC': price_vs_usdc}, ignore_index=True)
# C:\Users\Latitude\AppData\Local\Temp\ipykernel_12760\1613849081.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'Symbol': symbol, 'Price_vs_USDC': price_vs_usdc}, ignore_index=True)
# C:\Users\Latitude\AppData\Local\Temp\ipykernel_12760\1613849081.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'Symbol': symbol, 'Price_vs_USDC': price_vs_usdc}, ignore_index=True)
# C:\Users\Latitude\AppData\Local\Temp\ipykernel_12760\1613849081.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'Symbol': symbol, 'Price_vs_USDC': price_vs_usdc}, ignore_index=True)
# C:\Users\Latitude\AppData\Local\Temp\ipykernel_12760\1613849081.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'Symbol': symbol, 'Price_vs_USDC': price_vs_usdc}, ignore_index=True)
# C:\Users\Latitude\AppData\Local\Temp\ipykernel_12760\1613849081.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'Symbol': symbol, 'Price_vs_USDC': price_vs_usdc}, ignore_index=True)
# C:\Users\Latitude\AppData\Local\Temp\ipykernel_12760\1613849081.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'Symbol': symbol, 'Price_vs_USDC': price_vs_usdc}, ignore_index=True)
# C:\Users\Latitude\AppData\Local\Temp\ipykernel_12760\1613849081.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'Symbol': symbol, 'Price_vs_USDC': price_vs_usdc}, ignore_index=True)
# C:\Users\Latitude\AppData\Local\Temp\ipykernel_12760\1613849081.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'Symbol': symbol, 'Price_vs_USDC': price_vs_usdc}, ignore_index=True)
# C:\Users\Latitude\AppData\Local\Temp\ipykernel_12760\1613849081.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'Symbol': symbol, 'Price_vs_USDC': price_vs_usdc}, ignore_index=True)
# C:\Users\Latitude\AppData\Local\Temp\ipykernel_12760\1613849081.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'Symbol': symbol, 'Price_vs_USDC': price_vs_usdc}, ignore_index=True)
# C:\Users\Latitude\AppData\Local\Temp\ipykernel_12760\1613849081.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'Symbol': symbol, 'Price_vs_USDC': price_vs_usdc}, ignore_index=True)
# C:\Users\Latitude\AppData\Local\Temp\ipykernel_12760\1613849081.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'Symbol': symbol, 'Price_vs_USDC': price_vs_usdc}, ignore_index=True)
# Data not available for SOUL
# C:\Users\Latitude\AppData\Local\Temp\ipykernel_12760\1613849081.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'Symbol': symbol, 'Price_vs_USDC': price_vs_usdc}, ignore_index=True)
# C:\Users\Latitude\AppData\Local\Temp\ipykernel_12760\1613849081.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'Symbol': symbol, 'Price_vs_USDC': price_vs_usdc}, ignore_index=True)
# C:\Users\Latitude\AppData\Local\Temp\ipykernel_12760\1613849081.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'Symbol': symbol, 'Price_vs_USDC': price_vs_usdc}, ignore_index=True)
# C:\Users\Latitude\AppData\Local\Temp\ipykernel_12760\1613849081.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'Symbol': symbol, 'Price_vs_USDC': price_vs_usdc}, ignore_index=True)
# C:\Users\Latitude\AppData\Local\Temp\ipykernel_12760\1613849081.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'Symbol': symbol, 'Price_vs_USDC': price_vs_usdc}, ignore_index=True)
# Data not available for AVAX
# C:\Users\Latitude\AppData\Local\Temp\ipykernel_12760\1613849081.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'Symbol': symbol, 'Price_vs_USDC': price_vs_usdc}, ignore_index=True)
# C:\Users\Latitude\AppData\Local\Temp\ipykernel_12760\1613849081.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'Symbol': symbol, 'Price_vs_USDC': price_vs_usdc}, ignore_index=True)
# C:\Users\Latitude\AppData\Local\Temp\ipykernel_12760\1613849081.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'Symbol': symbol, 'Price_vs_USDC': price_vs_usdc}, ignore_index=True)
# C:\Users\Latitude\AppData\Local\Temp\ipykernel_12760\1613849081.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'Symbol': symbol, 'Price_vs_USDC': price_vs_usdc}, ignore_index=True)
# C:\Users\Latitude\AppData\Local\Temp\ipykernel_12760\1613849081.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'Symbol': symbol, 'Price_vs_USDC': price_vs_usdc}, ignore_index=True)
# C:\Users\Latitude\AppData\Local\Temp\ipykernel_12760\1613849081.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'Symbol': symbol, 'Price_vs_USDC': price_vs_usdc}, ignore_index=True)
# C:\Users\Latitude\AppData\Local\Temp\ipykernel_12760\1613849081.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'Symbol': symbol, 'Price_vs_USDC': price_vs_usdc}, ignore_index=True)
# C:\Users\Latitude\AppData\Local\Temp\ipykernel_12760\1613849081.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'Symbol': symbol, 'Price_vs_USDC': price_vs_usdc}, ignore_index=True)
# C:\Users\Latitude\AppData\Local\Temp\ipykernel_12760\1613849081.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'Symbol': symbol, 'Price_vs_USDC': price_vs_usdc}, ignore_index=True)
# C:\Users\Latitude\AppData\Local\Temp\ipykernel_12760\1613849081.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'Symbol': symbol, 'Price_vs_USDC': price_vs_usdc}, ignore_index=True)
# C:\Users\Latitude\AppData\Local\Temp\ipykernel_12760\1613849081.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'Symbol': symbol, 'Price_vs_USDC': price_vs_usdc}, ignore_index=True)
# C:\Users\Latitude\AppData\Local\Temp\ipykernel_12760\1613849081.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'Symbol': symbol, 'Price_vs_USDC': price_vs_usdc}, ignore_index=True)
# C:\Users\Latitude\AppData\Local\Temp\ipykernel_12760\1613849081.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'Symbol': symbol, 'Price_vs_USDC': price_vs_usdc}, ignore_index=True)
# C:\Users\Latitude\AppData\Local\Temp\ipykernel_12760\1613849081.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'Symbol': symbol, 'Price_vs_USDC': price_vs_usdc}, ignore_index=True)
# C:\Users\Latitude\AppData\Local\Temp\ipykernel_12760\1613849081.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'Symbol': symbol, 'Price_vs_USDC': price_vs_usdc}, ignore_index=True)
# C:\Users\Latitude\AppData\Local\Temp\ipykernel_12760\1613849081.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'Symbol': symbol, 'Price_vs_USDC': price_vs_usdc}, ignore_index=True)
# C:\Users\Latitude\AppData\Local\Temp\ipykernel_12760\1613849081.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'Symbol': symbol, 'Price_vs_USDC': price_vs_usdc}, ignore_index=True)
# C:\Users\Latitude\AppData\Local\Temp\ipykernel_12760\1613849081.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'Symbol': symbol, 'Price_vs_USDC': price_vs_usdc}, ignore_index=True)
# C:\Users\Latitude\AppData\Local\Temp\ipykernel_12760\1613849081.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'Symbol': symbol, 'Price_vs_USDC': price_vs_usdc}, ignore_index=True)
# C:\Users\Latitude\AppData\Local\Temp\ipykernel_12760\1613849081.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'Symbol': symbol, 'Price_vs_USDC': price_vs_usdc}, ignore_index=True)
# C:\Users\Latitude\AppData\Local\Temp\ipykernel_12760\1613849081.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'Symbol': symbol, 'Price_vs_USDC': price_vs_usdc}, ignore_index=True)
# C:\Users\Latitude\AppData\Local\Temp\ipykernel_12760\1613849081.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'Symbol': symbol, 'Price_vs_USDC': price_vs_usdc}, ignore_index=True)
# C:\Users\Latitude\AppData\Local\Temp\ipykernel_12760\1613849081.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'Symbol': symbol, 'Price_vs_USDC': price_vs_usdc}, ignore_index=True)
# C:\Users\Latitude\AppData\Local\Temp\ipykernel_12760\1613849081.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'Symbol': symbol, 'Price_vs_USDC': price_vs_usdc}, ignore_index=True)
# C:\Users\Latitude\AppData\Local\Temp\ipykernel_12760\1613849081.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'Symbol': symbol, 'Price_vs_USDC': price_vs_usdc}, ignore_index=True)
# C:\Users\Latitude\AppData\Local\Temp\ipykernel_12760\1613849081.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'Symbol': symbol, 'Price_vs_USDC': price_vs_usdc}, ignore_index=True)
# C:\Users\Latitude\AppData\Local\Temp\ipykernel_12760\1613849081.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'Symbol': symbol, 'Price_vs_USDC': price_vs_usdc}, ignore_index=True)
# C:\Users\Latitude\AppData\Local\Temp\ipykernel_12760\1613849081.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'Symbol': symbol, 'Price_vs_USDC': price_vs_usdc}, ignore_index=True)
# C:\Users\Latitude\AppData\Local\Temp\ipykernel_12760\1613849081.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'Symbol': symbol, 'Price_vs_USDC': price_vs_usdc}, ignore_index=True)
# C:\Users\Latitude\AppData\Local\Temp\ipykernel_12760\1613849081.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'Symbol': symbol, 'Price_vs_USDC': price_vs_usdc}, ignore_index=True)
# C:\Users\Latitude\AppData\Local\Temp\ipykernel_12760\1613849081.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'Symbol': symbol, 'Price_vs_USDC': price_vs_usdc}, ignore_index=True)
# C:\Users\Latitude\AppData\Local\Temp\ipykernel_12760\1613849081.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'Symbol': symbol, 'Price_vs_USDC': price_vs_usdc}, ignore_index=True)
# C:\Users\Latitude\AppData\Local\Temp\ipykernel_12760\1613849081.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'Symbol': symbol, 'Price_vs_USDC': price_vs_usdc}, ignore_index=True)
# C:\Users\Latitude\AppData\Local\Temp\ipykernel_12760\1613849081.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'Symbol': symbol, 'Price_vs_USDC': price_vs_usdc}, ignore_index=True)
# C:\Users\Latitude\AppData\Local\Temp\ipykernel_12760\1613849081.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'Symbol': symbol, 'Price_vs_USDC': price_vs_usdc}, ignore_index=True)
# C:\Users\Latitude\AppData\Local\Temp\ipykernel_12760\1613849081.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'Symbol': symbol, 'Price_vs_USDC': price_vs_usdc}, ignore_index=True)
# C:\Users\Latitude\AppData\Local\Temp\ipykernel_12760\1613849081.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'Symbol': symbol, 'Price_vs_USDC': price_vs_usdc}, ignore_index=True)
# C:\Users\Latitude\AppData\Local\Temp\ipykernel_12760\1613849081.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'Symbol': symbol, 'Price_vs_USDC': price_vs_usdc}, ignore_index=True)
# C:\Users\Latitude\AppData\Local\Temp\ipykernel_12760\1613849081.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'Symbol': symbol, 'Price_vs_USDC': price_vs_usdc}, ignore_index=True)
# C:\Users\Latitude\AppData\Local\Temp\ipykernel_12760\1613849081.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'Symbol': symbol, 'Price_vs_USDC': price_vs_usdc}, ignore_index=True)
# Data not available for GM
# C:\Users\Latitude\AppData\Local\Temp\ipykernel_12760\1613849081.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'Symbol': symbol, 'Price_vs_USDC': price_vs_usdc}, ignore_index=True)
# C:\Users\Latitude\AppData\Local\Temp\ipykernel_12760\1613849081.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'Symbol': symbol, 'Price_vs_USDC': price_vs_usdc}, ignore_index=True)
# C:\Users\Latitude\AppData\Local\Temp\ipykernel_12760\1613849081.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'Symbol': symbol, 'Price_vs_USDC': price_vs_usdc}, ignore_index=True)
# C:\Users\Latitude\AppData\Local\Temp\ipykernel_12760\1613849081.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'Symbol': symbol, 'Price_vs_USDC': price_vs_usdc}, ignore_index=True)
# C:\Users\Latitude\AppData\Local\Temp\ipykernel_12760\1613849081.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'Symbol': symbol, 'Price_vs_USDC': price_vs_usdc}, ignore_index=True)
# C:\Users\Latitude\AppData\Local\Temp\ipykernel_12760\1613849081.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'Symbol': symbol, 'Price_vs_USDC': price_vs_usdc}, ignore_index=True)
# C:\Users\Latitude\AppData\Local\Temp\ipykernel_12760\1613849081.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'Symbol': symbol, 'Price_vs_USDC': price_vs_usdc}, ignore_index=True)
# C:\Users\Latitude\AppData\Local\Temp\ipykernel_12760\1613849081.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'Symbol': symbol, 'Price_vs_USDC': price_vs_usdc}, ignore_index=True)
# C:\Users\Latitude\AppData\Local\Temp\ipykernel_12760\1613849081.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'Symbol': symbol, 'Price_vs_USDC': price_vs_usdc}, ignore_index=True)
# C:\Users\Latitude\AppData\Local\Temp\ipykernel_12760\1613849081.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'Symbol': symbol, 'Price_vs_USDC': price_vs_usdc}, ignore_index=True)
# C:\Users\Latitude\AppData\Local\Temp\ipykernel_12760\1613849081.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'Symbol': symbol, 'Price_vs_USDC': price_vs_usdc}, ignore_index=True)
# C:\Users\Latitude\AppData\Local\Temp\ipykernel_12760\1613849081.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'Symbol': symbol, 'Price_vs_USDC': price_vs_usdc}, ignore_index=True)
# C:\Users\Latitude\AppData\Local\Temp\ipykernel_12760\1613849081.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'Symbol': symbol, 'Price_vs_USDC': price_vs_usdc}, ignore_index=True)
# C:\Users\Latitude\AppData\Local\Temp\ipykernel_12760\1613849081.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'Symbol': symbol, 'Price_vs_USDC': price_vs_usdc}, ignore_index=True)
# C:\Users\Latitude\AppData\Local\Temp\ipykernel_12760\1613849081.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'Symbol': symbol, 'Price_vs_USDC': price_vs_usdc}, ignore_index=True)
# Data not available for NINJA
# C:\Users\Latitude\AppData\Local\Temp\ipykernel_12760\1613849081.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'Symbol': symbol, 'Price_vs_USDC': price_vs_usdc}, ignore_index=True)
# C:\Users\Latitude\AppData\Local\Temp\ipykernel_12760\1613849081.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'Symbol': symbol, 'Price_vs_USDC': price_vs_usdc}, ignore_index=True)
# C:\Users\Latitude\AppData\Local\Temp\ipykernel_12760\1613849081.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'Symbol': symbol, 'Price_vs_USDC': price_vs_usdc}, ignore_index=True)
# C:\Users\Latitude\AppData\Local\Temp\ipykernel_12760\1613849081.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'Symbol': symbol, 'Price_vs_USDC': price_vs_usdc}, ignore_index=True)
# C:\Users\Latitude\AppData\Local\Temp\ipykernel_12760\1613849081.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'Symbol': symbol, 'Price_vs_USDC': price_vs_usdc}, ignore_index=True)
# C:\Users\Latitude\AppData\Local\Temp\ipykernel_12760\1613849081.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'Symbol': symbol, 'Price_vs_USDC': price_vs_usdc}, ignore_index=True)
# C:\Users\Latitude\AppData\Local\Temp\ipykernel_12760\1613849081.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'Symbol': symbol, 'Price_vs_USDC': price_vs_usdc}, ignore_index=True)
# C:\Users\Latitude\AppData\Local\Temp\ipykernel_12760\1613849081.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'Symbol': symbol, 'Price_vs_USDC': price_vs_usdc}, ignore_index=True)
# C:\Users\Latitude\AppData\Local\Temp\ipykernel_12760\1613849081.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'Symbol': symbol, 'Price_vs_USDC': price_vs_usdc}, ignore_index=True)
# Data not available for ALL
# C:\Users\Latitude\AppData\Local\Temp\ipykernel_12760\1613849081.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'Symbol': symbol, 'Price_vs_USDC': price_vs_usdc}, ignore_index=True)
# C:\Users\Latitude\AppData\Local\Temp\ipykernel_12760\1613849081.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'Symbol': symbol, 'Price_vs_USDC': price_vs_usdc}, ignore_index=True)
# C:\Users\Latitude\AppData\Local\Temp\ipykernel_12760\1613849081.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'Symbol': symbol, 'Price_vs_USDC': price_vs_usdc}, ignore_index=True)
# C:\Users\Latitude\AppData\Local\Temp\ipykernel_12760\1613849081.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'Symbol': symbol, 'Price_vs_USDC': price_vs_usdc}, ignore_index=True)
# C:\Users\Latitude\AppData\Local\Temp\ipykernel_12760\1613849081.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'Symbol': symbol, 'Price_vs_USDC': price_vs_usdc}, ignore_index=True)
# C:\Users\Latitude\AppData\Local\Temp\ipykernel_12760\1613849081.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'Symbol': symbol, 'Price_vs_USDC': price_vs_usdc}, ignore_index=True)
# C:\Users\Latitude\AppData\Local\Temp\ipykernel_12760\1613849081.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'Symbol': symbol, 'Price_vs_USDC': price_vs_usdc}, ignore_index=True)
# C:\Users\Latitude\AppData\Local\Temp\ipykernel_12760\1613849081.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'Symbol': symbol, 'Price_vs_USDC': price_vs_usdc}, ignore_index=True)
# C:\Users\Latitude\AppData\Local\Temp\ipykernel_12760\1613849081.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'Symbol': symbol, 'Price_vs_USDC': price_vs_usdc}, ignore_index=True)
# C:\Users\Latitude\AppData\Local\Temp\ipykernel_12760\1613849081.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'Symbol': symbol, 'Price_vs_USDC': price_vs_usdc}, ignore_index=True)
# C:\Users\Latitude\AppData\Local\Temp\ipykernel_12760\1613849081.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'Symbol': symbol, 'Price_vs_USDC': price_vs_usdc}, ignore_index=True)
# C:\Users\Latitude\AppData\Local\Temp\ipykernel_12760\1613849081.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'Symbol': symbol, 'Price_vs_USDC': price_vs_usdc}, ignore_index=True)
# C:\Users\Latitude\AppData\Local\Temp\ipykernel_12760\1613849081.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'Symbol': symbol, 'Price_vs_USDC': price_vs_usdc}, ignore_index=True)
# C:\Users\Latitude\AppData\Local\Temp\ipykernel_12760\1613849081.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'Symbol': symbol, 'Price_vs_USDC': price_vs_usdc}, ignore_index=True)
# C:\Users\Latitude\AppData\Local\Temp\ipykernel_12760\1613849081.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'Symbol': symbol, 'Price_vs_USDC': price_vs_usdc}, ignore_index=True)
# C:\Users\Latitude\AppData\Local\Temp\ipykernel_12760\1613849081.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'Symbol': symbol, 'Price_vs_USDC': price_vs_usdc}, ignore_index=True)
# ...
#   result_df = result_df.append({'Symbol': symbol, 'Price_vs_USDC': price_vs_usdc}, ignore_index=True)
# C:\Users\Latitude\AppData\Local\Temp\ipykernel_12760\1613849081.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'Symbol': symbol, 'Price_vs_USDC': price_vs_usdc}, ignore_index=True)
# C:\Users\Latitude\AppData\Local\Temp\ipykernel_12760\1613849081.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'Symbol': symbol, 'Price_vs_USDC': price_vs_usdc}, ignore_index=True)
# C:\Users\Latitude\AppData\Local\Temp\ipykernel_12760\1613849081.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'Symbol': symbol, 'Price_vs_USDC': price_vs_usdc}, ignore_index=True)
# C:\Users\Latitude\AppData\Local\Temp\ipykernel_12760\1613849081.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'Symbol': symbol, 'Price_vs_USDC': price_vs_usdc}, ignore_index=True)
# C:\Users\Latitude\AppData\Local\Temp\ipykernel_12760\1613849081.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'Symbol': symbol, 'Price_vs_USDC': price_vs_usdc}, ignore_index=True)
# C:\Users\Latitude\AppData\Local\Temp\ipykernel_12760\1613849081.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'Symbol': symbol, 'Price_vs_USDC': price_vs_usdc}, ignore_index=True)
# C:\Users\Latitude\AppData\Local\Temp\ipykernel_12760\1613849081.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'Symbol': symbol, 'Price_vs_USDC': price_vs_usdc}, ignore_index=True)
# C:\Users\Latitude\AppData\Local\Temp\ipykernel_12760\1613849081.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'Symbol': symbol, 'Price_vs_USDC': price_vs_usdc}, ignore_index=True)
# C:\Users\Latitude\AppData\Local\Temp\ipykernel_12760\1613849081.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'Symbol': symbol, 'Price_vs_USDC': price_vs_usdc}, ignore_index=True)
# C:\Users\Latitude\AppData\Local\Temp\ipykernel_12760\1613849081.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'Symbol': symbol, 'Price_vs_USDC': price_vs_usdc}, ignore_index=True)
# C:\Users\Latitude\AppData\Local\Temp\ipykernel_12760\1613849081.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'Symbol': symbol, 'Price_vs_USDC': price_vs_usdc}, ignore_index=True)
# Data not available for sunSBR
# C:\Users\Latitude\AppData\Local\Temp\ipykernel_12760\1613849081.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'Symbol': symbol, 'Price_vs_USDC': price_vs_usdc}, ignore_index=True)
# C:\Users\Latitude\AppData\Local\Temp\ipykernel_12760\1613849081.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'Symbol': symbol, 'Price_vs_USDC': price_vs_usdc}, ignore_index=True)
# Data not available for srenBTC-10
# Data not available for srenBTC-9
# C:\Users\Latitude\AppData\Local\Temp\ipykernel_12760\1613849081.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'Symbol': symbol, 'Price_vs_USDC': price_vs_usdc}, ignore_index=True)
# Data not available for pBTC
# C:\Users\Latitude\AppData\Local\Temp\ipykernel_12760\1613849081.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'Symbol': symbol, 'Price_vs_USDC': price_vs_usdc}, ignore_index=True)
# C:\Users\Latitude\AppData\Local\Temp\ipykernel_12760\1613849081.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'Symbol': symbol, 'Price_vs_USDC': price_vs_usdc}, ignore_index=True)
# C:\Users\Latitude\AppData\Local\Temp\ipykernel_12760\1613849081.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'Symbol': symbol, 'Price_vs_USDC': price_vs_usdc}, ignore_index=True)
# C:\Users\Latitude\AppData\Local\Temp\ipykernel_12760\1613849081.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'Symbol': symbol, 'Price_vs_USDC': price_vs_usdc}, ignore_index=True)
# C:\Users\Latitude\AppData\Local\Temp\ipykernel_12760\1613849081.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'Symbol': symbol, 'Price_vs_USDC': price_vs_usdc}, ignore_index=True)
# C:\Users\Latitude\AppData\Local\Temp\ipykernel_12760\1613849081.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'Symbol': symbol, 'Price_vs_USDC': price_vs_usdc}, ignore_index=True)
# C:\Users\Latitude\AppData\Local\Temp\ipykernel_12760\1613849081.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'Symbol': symbol, 'Price_vs_USDC': price_vs_usdc}, ignore_index=True)
# C:\Users\Latitude\AppData\Local\Temp\ipykernel_12760\1613849081.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'Symbol': symbol, 'Price_vs_USDC': price_vs_usdc}, ignore_index=True)
# C:\Users\Latitude\AppData\Local\Temp\ipykernel_12760\1613849081.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'Symbol': symbol, 'Price_vs_USDC': price_vs_usdc}, ignore_index=True)
# C:\Users\Latitude\AppData\Local\Temp\ipykernel_12760\1613849081.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'Symbol': symbol, 'Price_vs_USDC': price_vs_usdc}, ignore_index=True)
# C:\Users\Latitude\AppData\Local\Temp\ipykernel_12760\1613849081.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'Symbol': symbol, 'Price_vs_USDC': price_vs_usdc}, ignore_index=True)
# C:\Users\Latitude\AppData\Local\Temp\ipykernel_12760\1613849081.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'Symbol': symbol, 'Price_vs_USDC': price_vs_usdc}, ignore_index=True)
# C:\Users\Latitude\AppData\Local\Temp\ipykernel_12760\1613849081.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'Symbol': symbol, 'Price_vs_USDC': price_vs_usdc}, ignore_index=True)
# C:\Users\Latitude\AppData\Local\Temp\ipykernel_12760\1613849081.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'Symbol': symbol, 'Price_vs_USDC': price_vs_usdc}, ignore_index=True)
# C:\Users\Latitude\AppData\Local\Temp\ipykernel_12760\1613849081.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'Symbol': symbol, 'Price_vs_USDC': price_vs_usdc}, ignore_index=True)
# C:\Users\Latitude\AppData\Local\Temp\ipykernel_12760\1613849081.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'Symbol': symbol, 'Price_vs_USDC': price_vs_usdc}, ignore_index=True)
# C:\Users\Latitude\AppData\Local\Temp\ipykernel_12760\1613849081.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'Symbol': symbol, 'Price_vs_USDC': price_vs_usdc}, ignore_index=True)
# C:\Users\Latitude\AppData\Local\Temp\ipykernel_12760\1613849081.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'Symbol': symbol, 'Price_vs_USDC': price_vs_usdc}, ignore_index=True)
# C:\Users\Latitude\AppData\Local\Temp\ipykernel_12760\1613849081.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'Symbol': symbol, 'Price_vs_USDC': price_vs_usdc}, ignore_index=True)
# C:\Users\Latitude\AppData\Local\Temp\ipykernel_12760\1613849081.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'Symbol': symbol, 'Price_vs_USDC': price_vs_usdc}, ignore_index=True)
# C:\Users\Latitude\AppData\Local\Temp\ipykernel_12760\1613849081.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'Symbol': symbol, 'Price_vs_USDC': price_vs_usdc}, ignore_index=True)
# C:\Users\Latitude\AppData\Local\Temp\ipykernel_12760\1613849081.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'Symbol': symbol, 'Price_vs_USDC': price_vs_usdc}, ignore_index=True)
# C:\Users\Latitude\AppData\Local\Temp\ipykernel_12760\1613849081.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'Symbol': symbol, 'Price_vs_USDC': price_vs_usdc}, ignore_index=True)
# C:\Users\Latitude\AppData\Local\Temp\ipykernel_12760\1613849081.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'Symbol': symbol, 'Price_vs_USDC': price_vs_usdc}, ignore_index=True)
# C:\Users\Latitude\AppData\Local\Temp\ipykernel_12760\1613849081.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'Symbol': symbol, 'Price_vs_USDC': price_vs_usdc}, ignore_index=True)
# C:\Users\Latitude\AppData\Local\Temp\ipykernel_12760\1613849081.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'Symbol': symbol, 'Price_vs_USDC': price_vs_usdc}, ignore_index=True)
# C:\Users\Latitude\AppData\Local\Temp\ipykernel_12760\1613849081.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'Symbol': symbol, 'Price_vs_USDC': price_vs_usdc}, ignore_index=True)
# C:\Users\Latitude\AppData\Local\Temp\ipykernel_12760\1613849081.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'Symbol': symbol, 'Price_vs_USDC': price_vs_usdc}, ignore_index=True)
# C:\Users\Latitude\AppData\Local\Temp\ipykernel_12760\1613849081.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'Symbol': symbol, 'Price_vs_USDC': price_vs_usdc}, ignore_index=True)
# C:\Users\Latitude\AppData\Local\Temp\ipykernel_12760\1613849081.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'Symbol': symbol, 'Price_vs_USDC': price_vs_usdc}, ignore_index=True)
# C:\Users\Latitude\AppData\Local\Temp\ipykernel_12760\1613849081.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'Symbol': symbol, 'Price_vs_USDC': price_vs_usdc}, ignore_index=True)
# C:\Users\Latitude\AppData\Local\Temp\ipykernel_12760\1613849081.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'Symbol': symbol, 'Price_vs_USDC': price_vs_usdc}, ignore_index=True)
# C:\Users\Latitude\AppData\Local\Temp\ipykernel_12760\1613849081.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'Symbol': symbol, 'Price_vs_USDC': price_vs_usdc}, ignore_index=True)
# C:\Users\Latitude\AppData\Local\Temp\ipykernel_12760\1613849081.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'Symbol': symbol, 'Price_vs_USDC': price_vs_usdc}, ignore_index=True)
# C:\Users\Latitude\AppData\Local\Temp\ipykernel_12760\1613849081.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'Symbol': symbol, 'Price_vs_USDC': price_vs_usdc}, ignore_index=True)
# C:\Users\Latitude\AppData\Local\Temp\ipykernel_12760\1613849081.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'Symbol': symbol, 'Price_vs_USDC': price_vs_usdc}, ignore_index=True)
# C:\Users\Latitude\AppData\Local\Temp\ipykernel_12760\1613849081.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'Symbol': symbol, 'Price_vs_USDC': price_vs_usdc}, ignore_index=True)

# %%
result_df.head()
# Out:
#   Symbol  Price_vs_USDC
# 0    SOL      95.658355
# 1   USDC       1.000000
# 2   USDT       0.999318
# 3   $WIF       0.368549
# 4   Bonk       0.000014

# %%
symbolvusdc_df = result_df[result_df['Price_vs_USDC'] >= 0.001]
print(symbolvusdc_df.head())
# Out:
#   Symbol  Price_vs_USDC
# 0    SOL      95.658355
# 1   USDC       1.000000
# 2   USDT       0.999318
# 3   $WIF       0.368549
# 5  $MYRO       0.136955

# %%
symbolvusdc = symbolvusdc_df[['Symbol']]
symbolvusdc.to_csv('symbolvUSDC.csv', index=False)

# %%
print(df.shape,
symbols.shape,
result_df.shape,
symbolvusdc_df.shape,
symbolvusdc.shape)
# Out:
# (697, 1) (697, 1) (683, 2) (441, 2) (441, 1)

# %%
symbolvusdc.head()
# Out:
#   Symbol
# 0    SOL
# 1   USDC
# 2   USDT
# 3   $WIF
# 5  $MYRO
